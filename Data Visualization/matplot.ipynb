# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('mpg_sns (1).csv')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df2=df.groupby('model_year')['mpg'].mean().reset_index()
df2
# Out:
#     model_year        mpg
# 0           70  17.689655
# 1           71  21.250000
# 2           72  18.714286
# 3           73  17.100000
# 4           74  22.703704
# 5           75  20.266667
# 6           76  21.573529
# 7           77  23.375000
# 8           78  24.061111
# 9           79  25.093103
# 10          80  33.696552
# 11          81  30.334483
# 12          82  31.709677

# %% [markdown]
# ##### Line Plot

# %%
plt.plot(df2['model_year'],df2['mpg'])
plt.xlabel('Model Year')
plt.ylabel('MPG')
plt.title('Model Year vs MPG')
plt.show()

# %% [markdown]
# ##### Scatter Plot

# %%
plt.scatter(df['mpg'],df['horsepower'])
plt.xlabel('MPG')
plt.ylabel('Horsepower')
plt.show()

# %% [markdown]
# ##### Bar Plot

# %%
sumdf=df['cylinders'].value_counts().reset_index()
plt.bar(sumdf['cylinders'],sumdf['count'])
plt.xlabel('Cylinder')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### Histogram

# %%
plt.hist(df['mpg'],edgecolor='black')
plt.show()

# %% [markdown]
# ##### Box Plot

# %%
sns.boxplot(x='origin',y='mpg',data=df)
plt.show()

# %% [markdown]
# ##### Violin Plot

# %%
plt.violinplot(dataset=[df[df['origin']==i]['mpg'] for i in df['origin'].unique()],positions=range(1,len(df['origin'].unique())+1),showmedians=True,vert=False,showextrema=True,showmeans=True)
plt.show()
